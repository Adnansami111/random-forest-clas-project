# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,r2_score,precision_score

# %%
df=pd.read_excel("random_forest_classification_dataset.xlsx")

# %%
df
# Out:
#           Age    Income  Credit_Score  Loan_Amount   Savings  Dependents  \
# 0   -2.514022  1.310668      1.765425     3.092741 -2.462735   -0.012782
# 1   -0.294476 -1.996736     -0.152621     1.397219 -0.683252    1.007496
# 2   -1.386362  0.369229      2.716417     0.840239 -0.845484    0.592481
# 3   -2.148744  0.410360      1.292912     1.124988 -1.928481   -1.352152
# 4   -1.540015 -1.629406      3.128660     0.288462  1.131187    0.134188
# ..        ...       ...           ...          ...       ...         ...
# 145  2.098719 -0.747319     -3.745072    -1.159533  1.464916    0.188989
# 146  0.233057  1.907575      0.116639    -2.047988  0.887267   -1.254614
# 147 -1.259657 -0.445426      1.968801    -1.269296  0.883664    0.564516
# 148 -1.035654  2.272841     -1.726967     1.309285  1.282992    1.345494
# 149  0.764982 -2.094044     -0.151577     0.389249 -0.989184    0.951178
#
#      Loan_Approved
# 0                0
# 1                1
# 2                0
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Income', 'Credit_Score', 'Loan_Amount', 'Savings', 'Dependents',
#        'Loan_Approved'],
#       dtype='object')

# %%
columns=['Age', 'Income', 'Credit_Score', 'Loan_Amount', 'Savings', 'Dependents','Loan_Approved']
for col in columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"{col}: {outliers.shape[0]} outliers")
# Out:
# Age: 1 outliers
# Income: 0 outliers
# Credit_Score: 1 outliers
# Loan_Amount: 1 outliers
# Savings: 1 outliers
# Dependents: 5 outliers
# Loan_Approved: 0 outliers

# %%
for col in columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
for col in columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"{col}: {outliers.shape[0]} outliers")
# Out:
# Age: 0 outliers
# Income: 0 outliers
# Credit_Score: 0 outliers
# Loan_Amount: 0 outliers
# Savings: 0 outliers
# Dependents: 0 outliers
# Loan_Approved: 0 outliers

# %%
X = df.drop("Loan_Approved",axis=1)

# %%
Y = df["Loan_Approved"]

# %%
scaler = StandardScaler()

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=42,test_size=0.2)

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
model = RandomForestClassifier(n_estimators = 12,max_depth=6,random_state=42)

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(max_depth=6, n_estimators=12, random_state=42)

# %%
Y_pred = model.predict(X_test)

# %%
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.8
